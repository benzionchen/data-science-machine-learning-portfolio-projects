# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd

# %%
ecom = pd.read_csv('Ecommerce Purchases')

ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# ** How many rows and columns are there? **

# %%
len(ecom.columns)

# for columns
# Out:
# 14

# %%
len(ecom.index)

# for rows
# Out:
# 10000

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom['Purchase Price'].max()
# Out:
# 99.99

# %%
ecom['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
ecom[ecom['Language']=='en']['Language'].count()

# when "ecom['Language'] == 'en']" is "True"... 
## the function simplifies to "ecom[True]['Language'].count()"
# we'll count how many times that 'ecom'-dataframe is "True" in the "Language" 
# column
# Out:
# 1098

# %%
ecom[ecom['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
def lawyer_title(jobTitle):
    if "lawyer" in jobTitle.lower().split():
        return True
    else: 
        return False

# %%
# writing a test case

lawyer_title("Chief")
# Out:
# False

# %%
# writing a test case

lawyer_title("LAWYER")
# Out:
# True

# %%
sum(ecom['Job'].apply(lambda x:lawyer_title(x)))
# Out:
# 30

# %%
ecom[ecom['Job'].lower() == 'lawyer']

# you can't use ".lower()" method on a series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15180\3245216347.py in <module>
# ----> 1 ecom[ecom['Job'].lower() == 'Lawyer']
#       2
#       3 # you can't use ".lower()" method on a series
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
ecom[ecom['Job'] == 'Lawyer']

# this returns the subset of the dataframe where this is true
# Out:
#                                                 Address    Lot AM or PM  \
# 470   9310 Bailey Mountain Apt. 832\nLake Jacqueline...  67 tQ       PM
# 508     5064 Nicole Circle\nJohnsonburgh, NM 78266-6283  53 rJ       PM
# 1275  4394 Sherry Row Suite 034\nSouth Rebecca, MD 6...  80 jP       PM
# 1569  91733 King Mountains Apt. 356\nSouth Tammy, NE...  20 Aa       AM
# 1682      5691 Fox Mountains\nDudleyside, GU 66765-2101  67 Bk       AM
# 2164  57897 Stacey Pass\nLake Jacquelinestad, MA 038...  61 DY       PM
# 2619   720 Laurie Plains Apt. 458\nChavezfurt, DE 05290  38 gp       AM
# 2935         816 Cheyenne Causeway\nHeidibury, FL 10365  70 nu       AM
# 3663       6218 Mendez Estate\nEast Kylemouth, MI 80812  63 BG       PM
# 3738   3921 Courtney River\nSouth Donaldmouth, AK 78115  85 Rh       AM
# 3966  3465 Hunter Streets Apt. 976\nMedinachester, W...  07 xf       PM
# 5053       88431 Thomas Stream\nMartinchester, WA 82488  19 fZ       PM
# ...

# %%
ecom[ecom['Job'] == 'Lawyer'].info()

# this will return how many entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 470 to 9979
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           30 non-null     object
#  1   Lot               30 non-null     object
#  2   AM or PM          30 non-null     object
#  3   Browser Info      30 non-null     object
#  4   Company           30 non-null     object
#  5   Credit Card       30 non-null     int64
#  6   CC Exp Date       30 non-null     object
#  7   CC Security Code  30 non-null     int64
#  8   CC Provider       30 non-null     object
#  9   Email             30 non-null     object
#  10  Job               30 non-null     object
#  11  IP Address        30 non-null     object
#  12  Language          30 non-null     object
#  13  Purchase Price    30 non-null     float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 3.5+ KB

# %%
ecom[ecom['Job'] == 'Lawyer'].count()

# you can also do ".count()" for a count of 30 rows
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
ecom[ecom['Job'] == 'Lawyer'].index

# this will return the indices that have the word "Lawyer" in it
# Out:
# Int64Index([ 470,  508, 1275, 1569, 1682, 2164, 2619, 2935, 3663, 3738, 3966,
#             5053, 5339, 5452, 5562, 5974, 6131, 6136, 6220, 7368, 7645, 8127,
#             8220, 8620, 8683, 8801, 8860, 9175, 9659, 9979],
#            dtype='int64')

# %%
len(ecom[ecom['Job'] == 'Lawyer'].index)
# Out:
# 30

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
ecom['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
ecom[ecom['Lot'] == '90 WT']['Purchase Price']

# "ecom[ecom['Lot'] == '90 WT']" serves as the row, and "['Purchase Price']" is the column, it's indexing [row][column]
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
ecom[ecom['Credit Card'] == 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
ecom[ecom['CC Provider'] == "American Express"]

# this is all people who have American Express
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 17    950 Jacqueline Village Apt. 592\nPort Kimberly...  23 Rh       PM
# 37           86777 Mary Crescent\nCarloshaven, KY 48326  10 LL       AM
# 45    096 Edwards Valleys Suite 917\nPerkinsberg, LA...  07 Cd       PM
# 51           735 Gaines Plains\nRyanfurt, GU 29451-6616  50 Ds       PM
# ...                                                 ...    ...      ...
# 9942           03874 Richard Isle\nNew Steven, TX 25541  13 An       PM
# 9944  67427 Mitchell Roads Apt. 905\nEast Christinev...  13 mI       AM
# 9965  2268 Austin Village Apt. 542\nWest Meghan, CA ...  03 hK       AM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...

# %%
ecom[ecom['Purchase Price'] > 95.00].nunique()

# 505 people have made purchases above $95
# Out:
# Address             505
# Lot                 505
# AM or PM              2
# Browser Info        491
# Company             495
# Credit Card         505
# CC Exp Date         119
# CC Security Code    403
# CC Provider          10
# Email               504
# Job                 332
# IP Address          505
# Language              9
# Purchase Price      329
# dtype: int64

# %%
# this is conditional selection with multiple conditions

ecom[ecom['CC Provider'] == "American Express"][ecom['Purchase Price'] > 95.00].nunique()
# Out:
# C:\Users\raiu\AppData\Local\Temp\ipykernel_15180\3274916331.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ecom[ecom['CC Provider'] == "American Express"][ecom['Purchase Price'] > 95.00].nunique()
# Address             39
# Lot                 39
# AM or PM             2
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         36
# CC Security Code    38
# CC Provider          1
# Email               39
# Job                 36
# IP Address          39
# Language             9
# Purchase Price      38
# dtype: int64

# %%
# the lecture wrote: 

ecom[(ecom['CC Provider'] == "American Express") & (ecom['Purchase Price']>95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
# confirm whether the value inside the cell under the CC expiration date column is a string or an integer
# we can test this using the 0th row cell

ecom['CC Exp Date'].iloc[0]
# Out:
# '02/20'

# %%
sum(ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25'))

# for every cell's value under the "CC Exp Date" column, we apply the lambda expression to only index from the 3rd index onward
# and see which yields true

# and from that, we sum all the numbers of "True"
# Out:
# 1033

# %%
ecom[ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25')].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
ecom['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
ecom['Email'].nunique()

# the number of emails are all unique... because they're all different
# Out:
# 9954

# %%
ecom['Email'].apply(lambda email: email.split("@")[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# # Great Job!
